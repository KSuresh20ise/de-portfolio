# %%
# lambda function anonymous function which doesnt require name and variable to stote
# syntax lambda arguments: expression
# No return statement is required

# %%
# custom average function

def average(*x):
    return sum(x)/len(x)
print(average(1,2,3,4,5))
# Out:
# 3.0

# %%
# using lambda function
print((lambda x : sum(x)/len(x)) ([1,2,3,4,5]))
# Out:
# 3.0

# %%
avg = lambda x: sum(x)/len(x)
print(avg([1,2,3,4,5]))
# Out:
# 3.0

# %%
# Multiple parameters

power  =lambda x,y: x**y
print(power(2,3))
# Out:
# 8

# %%
# lambda function with iterables
# map() function applies to all elements in an iterable

alpha = ["a","b","c","d"]
captalize = map(lambda x: x.capitalize(), aipha)
print(list(captalize))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       1 # lambda function with iterables
#       2 # map() function applies to all elements in an iterable
#       4 alpha = ["a","b","c","d"]
# ----> 5 captalize = map(lambda x: x.capitalize(), names)
#       6 print(list(captalize))
#
# NameError: name 'names' is not defined
